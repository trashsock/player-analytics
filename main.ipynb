# %%
# Install dependencies
! pip install streamlit pyngrok torch sklearn deap plotly pandas reportlab

# %%
# Import modules
from data_generator import generate_league_data
from train import train_models

# %%
# User inputs
sport = input("Enter sport (AFL/NRL): ").upper()
user_type = input("Enter user type (pro/fan): ").lower()

# Generate league data
main_data, gps_data, config = generate_league_data(sport=sport)

# %%
# Train models
train_models(f'league_stats_{sport}.csv', sport=sport)
