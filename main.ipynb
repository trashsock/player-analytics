# %%
! pip install streamlit pyngrok torch sklearn deap plotly pandas

# %%
# Import modules
from data_generator import generate_synthetic_data
from model_trainer import train_models
from query_app import run_query_app

# %%
# Generate synthetic data
# main_data, gps_data = generate_synthetic_data()

output_file='broncos_2025_stats.csv'

# Train models
train_models(output_file)

# Launch Streamlit app
# !ngrok authtoken [YOUR_TOKEN]  # Get from ngrok.com
from pyngrok import ngrok
public_url = ngrok.connect(8501)
print(f"Demo URL: {public_url}")
# !streamlit run query_app.py &
